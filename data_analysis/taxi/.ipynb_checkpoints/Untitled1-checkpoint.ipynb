# %%
import pandas as pd
data=pd.read_csv("./sum_cluster.csv")
data
# Out:
#      Unnamed: 0      lat       lon  value
# 0             0  35.9681  128.4651    4.4
# 1             1  35.9681  128.4751    9.8
# 2             2  35.9681  128.4851   37.3
# 3             3  35.9681  128.4951    3.5
# 4             4  35.9681  128.5051    0.3
# ..          ...      ...       ...    ...
# 505         505  35.8081  128.7151    0.7
# 506         506  35.8081  128.7251   10.8
# 507         507  35.8081  128.7351  791.4
# 508         508  35.8081  128.7451  125.3
# 509         509  35.8081  128.7551  123.4
#
# [510 rows x 4 columns]

# %%
import folium
map_osm = folium.Map(location=[35.8796687,128.4266147], zoom_start=13)
#card_data_place.dropna()

for i in range(0,len(data.index)):
    lat1=data.loc[i,'lat']
    lon1=data.loc[i,'lon']
    if data.loc[i,'value']>0:
        print(i,data.loc[i,'value'])
        folium.CircleMarker([lat1,lon1],radius=data.loc[i,'value']/10000,popup=data.loc[i,'value'],color='red',fill=True).add_to(map_osm)
map_osm.save('sum_cluster.html')
# Out:
# 0 4.4
# 1 9.8
# 2 37.3
# 3 3.5
# 4 0.3
# 6 0.7
# 7 1.4
# 8 233.4
# 9 7919.46
# 10 22.5
# 11 33.3
# 12 32.0
# 13 2.7
# 14 0.7
# 16 181.1
# 17 0.3
# 18 0.7
# 19 10.9
# 20 18.9
# 21 38.1
# 22 1.7
# 23 184.9
# 24 291.5
# 25 51.0
# 26 24.8
# 27 330.3
# 28 7.999999999999999
# 30 4.199999999999998
# 31 41.2
# 32 67.7
# 33 6.4
# 34 2.1
# 36 7.399999999999999
# 37 10.6
# 38 9216.9
# 39 5287.17
# 40 13995.1
# 41 4709.5
# 42 2.3999999999999995
# 44 12.2
# 45 1.6
# 46 52.1
# 47 0.7
# 48 31.4
# 49 63.0
# 50 333.4
# 51 542.8
# 52 2539.2
# 53 94.0
# 54 172.4
# 55 4.499999999999999
# 56 1.4
# 58 1.0
# 59 0.3
# 60 6.9
# 62 10.7
# 63 1.6
# 64 4.6
# 65 0.3
# 66 9.3
# 67 7475.0
# 68 31466.7
# 69 144373.52
# 70 28819.0
# 71 2059.8
# 72 35.1
# 73 6.8
# 74 42.5
# 75 502.8
# 76 96.2
# 77 11926.5
# 78 4458.4
# 82 0.7
# 83 0.7
# 86 0.7
# 90 18.9
# 91 4.0
# 92 12.4
# 93 0.7
# 94 7.1
# 95 40.4
# 96 40.0
# 97 17539.1
# 98 80150.81999999999
# 99 59798.8
# 100 4761.8
# 101 0.7
# 102 46.6
# 103 1900.0
# 104 47.4
# ...
