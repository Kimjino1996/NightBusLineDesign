# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns; sns.set()
import mglearn
import csv

# %%
import pandas as pd
data=pd.read_csv("C:/Users/jino/Desktop/refined_taxi7.csv")
data
# Out:
#          START_X     START_Y   ARRIVE_X    ARRIVE_Y
# 0        START_X      START_   ARRIVE_X     ARRIVE_
# 1       35.94256  128.562863  35.855793  128.547588
# 2      35.825766   128.62521  35.829548  128.734976
# 3      35.817025   128.52248  35.853608  128.480621
# 4      35.808406   128.54516  35.803238  128.493755
# ...          ...         ...        ...         ...
# 74586  35.853483   128.54577  35.852353  128.523096
# 74587  35.873758   128.59471  35.867356  128.548384
# 74588   35.87591  128.554968  35.900045  128.548538
# 74589  35.837443   128.53372  35.860581  128.505026
# 74590   35.85921  128.504018  35.803478   128.49379
#
# [74591 rows x 4 columns]

# %%
data=data.drop(0)

# %%
data
# Out:
#          START_X     START_Y   ARRIVE_X    ARRIVE_Y
# 1       35.94256  128.562863  35.855793  128.547588
# 2      35.825766   128.62521  35.829548  128.734976
# 3      35.817025   128.52248  35.853608  128.480621
# 4      35.808406   128.54516  35.803238  128.493755
# 5      35.844656   128.54456  35.830705  128.546111
# ...          ...         ...        ...         ...
# 74586  35.853483   128.54577  35.852353  128.523096
# 74587  35.873758   128.59471  35.867356  128.548384
# 74588   35.87591  128.554968  35.900045  128.548538
# 74589  35.837443   128.53372  35.860581  128.505026
# 74590   35.85921  128.504018  35.803478   128.49379
#
# [74590 rows x 4 columns]

# %%
data[data.columns[0:2]]
# Out:
#          START_X     START_Y
# 1       35.94256  128.562863
# 2      35.825766   128.62521
# 3      35.817025   128.52248
# 4      35.808406   128.54516
# 5      35.844656   128.54456
# ...          ...         ...
# 74586  35.853483   128.54577
# 74587  35.873758   128.59471
# 74588   35.87591  128.554968
# 74589  35.837443   128.53372
# 74590   35.85921  128.504018
#
# [74590 rows x 2 columns]

# %%
data_cut=data[:10000]

# %%
data_cut[data_cut.columns[0:2]]
# Out:
#          START_X     START_Y
# 1       35.94256  128.562863
# 2      35.825766   128.62521
# 3      35.817025   128.52248
# 4      35.808406   128.54516
# 5      35.844656   128.54456
# ...          ...         ...
# 9996   35.857183   128.57410
# 9997   35.838868   128.57687
# 9998   35.849425   128.61290
# 9999   35.885086   128.58166
# 10000  35.823558   128.53382
#
# [10000 rows x 2 columns]

# %%
'''from sklearn.cluster import DBSCAN

data1_arr=data1[data1.columns[0:2]].to_numpy()
data1_arr=data1_arr.astype(float)

scaler = StandardScaler()
scaler.fit(data1_arr)
data_scaled = scaler.transform(data1_arr)

dbscan = DBSCAN(eps=0.5,min_samples=4)
clusters = dbscan.fit_predict(data_scaled )


plt.scatter(data_scaled[:,0], data_scaled[:,1], c=clusters, cmap=mglearn.cm2, s=60, edgecolors='black')
plt.rc('font', family='Malgun Gothic')
plt.xlabel("특성 0")
plt.rc('font', family='Malgun Gothic')
plt.ylabel("특성 1")

#for i in range(0,len(clusters)):
#    print(clusters[i])
'''
# Out:
# Text(0, 0.5, '특성 1')
# C:\Users\jino\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jino\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from sklearn.cluster import DBSCAN

data_cut_arr=data_cut[data_cut.columns[0:2]].to_numpy()
data_cut_arr=data_cut_arr.astype(float)


dbscan = DBSCAN(eps=0.01,min_samples=1)
clusters = dbscan.fit_predict(data_cut_arr )


plt.scatter(data_cut_arr[:,0], data_cut_arr[:,1], c=clusters, cmap=mglearn.cm2, s=20, edgecolors='black')
plt.rc('font', family='Malgun Gothic')
plt.xlabel("특성 0")
plt.rc('font', family='Malgun Gothic')
plt.ylabel("특성 1")

#for i in range(0,len(clusters)):
#    print(clusters[i])
# Out:
# Text(0, 0.5, '특성 1')

# %%
clusters
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.datasets import make_moons
from sklearn.metrics.cluster import adjusted_rand_score
from sklearn.metrics.cluster import silhouette_score
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

X, y = make_moons(n_samples=200, noise=0.05, random_state=0)
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)

X[:,0]
# Out:
# array([ 0.81680544,  1.61859642, -0.02126953, -1.02181041,  1.76654633,
#         1.8820287 ,  0.97481551,  0.88798782,  0.89865156,  1.11638974,
#        -0.36380036,  0.24702417,  1.81658658,  1.2163905 , -0.8236696 ,
#         0.98065583,  0.54097175,  0.348031  ,  0.35181497, -0.77708642,
#         1.92590813,  0.86096723,  0.19990695,  1.2895301 , -0.27847636,
#         0.24187916,  1.84988768,  1.88406869,  0.165822  ,  0.13861369,
#         0.89087024, -0.22806587,  0.98279208,  0.04237749,  0.76422612,
#         1.91108938,  0.43608432,  0.96186938, -0.84336684, -0.04122466,
#         0.55507653, -0.4388286 ,  0.6532646 ,  0.10274835,  1.5486824 ,
#        -0.37318371,  1.01706978, -0.71923685,  0.16135772,  0.86434045,
#        -0.69717533,  0.32791175,  1.98046734, -0.90479784,  1.04515397,
#         0.7534213 ,  0.54968577,  1.24038086,  0.24918868, -0.20756105,
#         0.35136403, -1.01628753,  1.78137056,  0.87423825,  1.09997644,
# ...

# %%
from sklearn.datasets import make_moons
from sklearn.metrics.cluster import adjusted_rand_score
from sklearn.metrics.cluster import silhouette_score
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

X, y = make_moons(n_samples=200, noise=0.05, random_state=0)
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)

dbscan = DBSCAN()
clusters = dbscan.fit_predict(X_scaled)
 # 클러스터 할당을 표시합니다
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=clusters, cmap=mglearn.cm2, s=60, edgecolors='black')
plt.xlabel("feature 0")
plt.ylabel("feature 1")
# Out:
# array([[ 0.36748451,  0.54576641],
#        [ 1.28731953, -1.2803031 ],
#        [-0.59397643,  0.04357482],
#        [-1.74182239, -0.66371706],
#        [ 1.45705144, -0.85667812],
#        [ 1.58953574, -0.59675854],
#        [ 0.54875768, -0.08552893],
#        [ 0.44914675, -1.50218876],
#        [ 0.46138047,  0.23124986],
#        [ 0.71117525, -1.59382202],
#        [-0.98693652,  1.16613579],
#        [-0.28618307, -0.9941549 ],
#        [ 1.51445888, -0.7760272 ],
#        [ 0.82589866, -1.33505302],
#        [-1.51451022,  0.79027655],
#        [ 0.55545785, -0.08853775],
#        [ 0.05104108,  1.284163  ],
#        [-0.17030547, -1.12065006],
#        [-0.1659644 ,  1.28843594],
#        [-1.46106881,  1.15527198],
#        [ 1.63987535, -0.48630812],
#        [ 0.41814803, -1.47618916],
#        [-0.34023715,  1.50810931],
#        [ 0.90980627, -1.26183242],
#        [-0.88905065,  1.56616629],
#        [-0.29208555, -0.66541512],
#        [ 1.55266276, -0.70888274],
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns; sns.set()
import mglearn
import csv

# %%
import pandas as pd
data=pd.read_csv("C:/Users/jino/Desktop/refined_taxi7.csv")
data
data=data.drop(0)

# %%
data_cut=data[:50000]

# %%
'''from sklearn.cluster import DBSCAN




dbscan = DBSCAN(eps=0.01,min_samples=1)
clusters = dbscan.fit_predict(data_cut_arr )


plt.scatter(data_cut_arr[:,0], data_cut_arr[:,1], c=clusters, cmap=mglearn.cm2, s=20, edgecolors='black')
plt.rc('font', family='Malgun Gothic')
plt.xlabel("특성 0")
plt.rc('font', family='Malgun Gothic')
plt.ylabel("특성 1")

#for i in range(0,len(clusters)):
#    print(clusters[i])
'''

# %%
from sklearn.cluster import AgglomerativeClustering


'''
plt.scatter(data_X[:],data_Y[:], s=1)
plt.show()
'''
data_cut_arr=data_cut[data_cut.columns[0:2]].to_numpy()
data_cut_arr=data_cut_arr.astype(float)

agg = AgglomerativeClustering(n_clusters=5)
assignment = agg.fit_predict(data_cut_arr)

#print(assignment.type)

mglearn.discrete_scatter(data_cut_arr[:,0], data_cut_arr[:,1], assignment)
plt.legend(range(0,30), loc="best")
plt.xlabel("feature 0")
plt.ylabel("feature 1")
# Out:
# Text(0, 0.5, 'feature 1')

# %%
assign=pd.DataFrame(assignment)
data_cut['label']=assign[0]

# %%
data_cut
# Out:
#         START_X     START_Y   ARRIVE_X    ARRIVE_Y  label
# 1      35.94256  128.562863  35.855793  128.547588   22.0
# 2     35.825766   128.62521  35.829548  128.734976   29.0
# 3     35.817025   128.52248  35.853608  128.480621   25.0
# 4     35.808406   128.54516  35.803238  128.493755   16.0
# 5     35.844656   128.54456  35.830705  128.546111   11.0
# ...         ...         ...        ...         ...    ...
# 9994  35.851948   128.62533  35.859888  128.615748    5.0
# 9995    35.8739  128.600938  35.880393  128.566403    9.0
# 9996  35.857183   128.57410  35.821043   128.51887   26.0
# 9997  35.838868   128.57687  35.852345  128.605528   18.0
# 9998  35.849425   128.61290  35.858071  128.643666    NaN
#
# [9998 rows x 5 columns]

# %%
data_cut=data_cut.dropna(axis=0)

data_cut1=data_cut.drop(data_cut.loc[data_cut['label'] > 2 ].index )

data_cut_arr=data_cut1[data_cut1.columns[0:2]].to_numpy()
data_cut_arr=data_cut_arr.astype(float)

# %%
data_cut1
# Out:
#         START_X     START_Y   ARRIVE_X    ARRIVE_Y  label
# 55    35.931733   128.55553  35.883118  128.661405    2.0
# 66    35.887813   128.65358  35.897696  128.632338    1.0
# 69     35.82521  128.621726  35.851801  128.537156    1.0
# 75    35.866438   128.56689  35.833676  128.621706    0.0
# 79    35.855325   128.50480  35.859306  128.499556    0.0
# ...         ...         ...        ...         ...    ...
# 9974  35.878823   128.57133  35.884731  128.567461    2.0
# 9979  35.874328    128.6287  35.874185  128.587756    0.0
# 9986   35.80642  128.499815  35.806435  128.499788    0.0
# 9989  35.814148   128.52454   35.85639  128.522318    2.0
# 9992  35.855568   128.52217  35.887895  128.593158    2.0
#
# [1604 rows x 5 columns]

# %%
assign=data_cut1[data_cut1.columns[4]].to_numpy()
assign.astype(int)
# Out:
# array([2, 1, 1, ..., 0, 2, 2])

# %%
mglearn.discrete_scatter(data_cut_arr[:,0], data_cut_arr[:,1], assign)
plt.legend(range(0,2), loc="best")
plt.xlabel("feature 0")
plt.ylabel("feature 1")
# Out:
# Text(0, 0.5, 'feature 1')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-b56cf81d4595> in <module>
# ----> 1 assign.index
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
kmeans = KMeans(n_clusters = 20, init ='random')
kmeans.fit(data[data.columns[0:2]]) # Compute k-means clustering.
data['cluster_label'] = kmeans.fit_predict(data[data.columns[0:2]])
centers = kmeans.cluster_centers_ # Coordinates of cluster centers.
labels = kmeans.predict(data[data.columns[0:2]]) # Labels of each point
data.head(10)
# Out:
#       START_X     START_Y   ARRIVE_X    ARRIVE_Y  cluster_label
# 1    35.94256  128.562863  35.855793  128.547588              4
# 2   35.825766   128.62521  35.829548  128.734976             10
# 3   35.817025   128.52248  35.853608  128.480621             16
# 4   35.808406   128.54516  35.803238  128.493755             11
# 5   35.844656   128.54456  35.830705  128.546111              2
# 6   35.941906   128.57018  35.926963  128.559258              4
# 7   35.827008     128.718  35.836973  128.716281             14
# 8   35.859141   128.49961  35.840221  128.566123              6
# 9    35.80791  128.520131    35.8529  128.480556             16
# 10  35.807748   128.51961  35.823531   128.64131             16

# %%
labels
# Out:
# array([ 4, 10, 16, ...,  8,  1,  6])

# %%
data1=data[data['cluster_label']==4]
data1_X=data1.loc[:,'START_X'].to_numpy()
data1_Y=data1.loc[:,'START_Y'].to_numpy()
data1_X=data1_X.astype(float)
data1_Y=data1_Y.astype(float)
plt.scatter(data1_X[:],data1_Y[:], s=1)
plt.show()

# %%
#data.plot.scatter(x = 'START_X', y = 'START_Y', c=labels, s=1, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=1, alpha=0.5)
plt.show()
